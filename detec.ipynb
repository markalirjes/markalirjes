# %%
import torch
from IPython.display import Image
import yolov5

# !python detect.py --source C:\xampp\htdocs\ada\yolov5\la.jpg --classes 0
Image('runs\detect\exp8\la.jpg')
# Out:
# detect: weights=yolov5s.pt, source=C:\xampp\htdocs\ada\yolov5\la.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-228-g4d687c8 Python-3.10.11 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 C:\xampp\htdocs\ada\yolov5\la.jpg: 352x640 14 persons, 208.6ms
# Speed: 0.0ms pre-process, 208.6ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp9
